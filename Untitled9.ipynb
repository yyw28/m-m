# %%
index_data={}
tickers_stock=['BILI', 'BABA','MSFT','GOOG','CRM','ZM','AMZN','DGX','LH','WDAY']
tickers_index=['^IRX','^GSPC']
for ticker in tickers_stock:
    stock_data[ticker]=web.get_data_yahoo(ticker,'1/1/2007','3/12/2020')
stock_price=pd.DataFrame({tic:data['Adj Close'] for tic, data in stock_data.items()})
stock_volume=pd.DataFrame({tic:data['Volume'] for tic, data in stock_data.items()})

for ticker in tickers_index:
    index_data[ticker]=web.get_data_yahoo(ticker,'1/1/2007','3/12/2020')
index_price=pd.DataFrame({tic:data['Adj Close'] for tic, data in index_data.items()})
# Out:
#                  BILI        BABA        MSFT         GOOG         CRM  \
# Date
# 2007-01-03        NaN         NaN   22.185307   232.921951    9.017500
# 2007-01-04        NaN         NaN   22.148153   240.727692    9.470000
# 2007-01-05        NaN         NaN   22.021847   242.685349    9.880000
# 2007-01-08        NaN         NaN   22.237307   240.887100    9.982500
# 2007-01-09        NaN         NaN   22.259609   241.843506    9.990000
# ...               ...         ...         ...          ...         ...
# 2020-03-06  26.680000  204.639999  161.570007  1298.410034  164.080002
# 2020-03-09  25.120001  197.660004  150.619995  1215.560059  151.210007
# 2020-03-10  26.000000  206.389999  160.919998  1280.390015  161.339996
# 2020-03-11  25.670000  198.910004  153.630005  1215.410034  154.570007
# 2020-03-12  23.799999  185.100006  139.059998  1114.910034  140.589996
#
#                     ZM         AMZN         DGX          LH        WDAY
# Date
# ...

# %%
daily_returns = stock_price.pct_change(1)
rf=index_price['^IRX']/252
for ticker in tickers_stock:
    excess_return_stock=daily_returns['AMZN'].dropna()-rf
excess_return_stock=excess_return_stock.dropna()

for ticker in tickers_stock:
    excess_return_market=index_price['^GSPC'].dropna()-rf
excess_return_market=excess_return_market.dropna()
X = excess_return_market
y = excess_return_stock
result = pd.concat([X, y], axis=1, join='inner')

# %%
X=result[0]
y=result[1]
# make regression model 
model = sm.OLS(y, X)
# fit model and print results
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      1   R-squared (uncentered):                   0.009
# Model:                            OLS   Adj. R-squared (uncentered):              0.009
# Method:                 Least Squares   F-statistic:                              29.28
# Date:                Fri, 13 Mar 2020   Prob (F-statistic):                    6.72e-08
# Time:                        21:51:43   Log-Likelihood:                          7485.7
# No. Observations:                3289   AIC:                                 -1.497e+04
# Df Residuals:                    3288   BIC:                                 -1.496e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X=result[0]
y=result[1]
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(X, y)
print(slope)
# Out:
# -2.065304043502165e-06

# %%
# Add a constant to the independent value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-b48b1dd1afc9> in <module>
#       6 X1 = sm.add_constant(X)
#       7 # make regression model
# ----> 8 model = sm.OLS(y, X1)
#       9 # fit model and print results
#      10 results = model.fit()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
# ...

# %%
price_after_v=daily_returns.loc['2020-02-01':'2020-03-13']
plt.plot(price_after_v)
plt.legend(daily_returns, loc='upper left')
plt.show()

# %%
import quandl
quandl.ApiConfig.api_key = "cV-q1ZpU7WjeHfuwyY-_"#"https://www.quandl.com"
#cV-q1ZpU7WjeHfuwyY-_
df = quandl.get_table("WIKI/PRICES?", ticker = ["MSFT"], qopts = {"columns": ["date", "ticker", "adj_open", "adj_close"]}, paginate=True)

# %%
#log_return=all_data['AAPL']['Log_Ret']=np.log(all_data['AAPL']['Close']/all_data['AAPL']['Close'].shift(1))
#log_return
